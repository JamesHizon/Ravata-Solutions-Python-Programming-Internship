# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Try writing out steps first on what to do. What are we trying to do?

# GREAT RESOURCES: 
# - YOUTUBE (sentdex, etc.)
# - Towards Data Science
# - Stack Overflow

# Well 1
df1 = pd.read_csv('/home/james/Downloads/Well__1.txt')

df1.head(16)
# Out:
#    Voltage Frequency     Impedance     Phase  Conductance  Susceptance  \
# 0    10 MV     10KHZ  2.162940e-10   1.38698     0.000019     0.000014
# 1    10 MV     10KHZ  4.326830e+04 -36.13920     0.000019     0.000014
# 2    10 MV     10KHZ  4.323080e+04 -36.17210     0.000019     0.000014
# 3    10 MV     10KHZ  4.333180e+04 -36.18690     0.000019     0.000014
# 4    10 MV     10KHZ  4.326040e+04 -36.24200     0.000019     0.000014
# 5    10 MV     10KHZ  4.333480e+04 -36.37730     0.000019     0.000014
# 6    10 MV     10KHZ  4.332110e+04 -36.33100     0.000019     0.000014
# 7    10 MV     10KHZ  4.340660e+04 -36.33170     0.000019     0.000014
# 8    10 MV     20KHZ  3.584830e+04 -22.89520     0.000026     0.000011
# 9    10 MV     20KHZ  3.588130e+04 -22.95290     0.000026     0.000011
# 10   10 MV     20KHZ  3.582220e+04 -22.88830     0.000026     0.000011
# 11   10 MV     20KHZ  3.579640e+04 -22.91670     0.000026     0.000011
# ...

# %%
# NOTICE:

# Want to work with the following condition:

# for df1['Voltage']=df1['Frequency']
    # Use .assign() to assign it to a particular.


# Well 2
df2 = pd.read_csv('/home/james/Downloads/Well__2.txt')

df2.head(16)
# Out:
#    Voltage Frequency  Impedance         Phase   Conductance   Susceptance  \
# 0    10 MV     10KHZ   252408.0 -4.146520e+06  9.900000e+37  9.900000e+37
# 1    10 MV     10KHZ    54270.0 -3.726340e+01  1.462810e-05  1.116690e-05
# 2    10 MV     10KHZ    54385.8 -3.723460e+01  1.467170e-05  1.116130e-05
# 3    10 MV     10KHZ    54328.7 -3.740630e+01  1.468240e-05  1.113800e-05
# 4    10 MV     10KHZ    54222.9 -3.729750e+01  1.465060e-05  1.112140e-05
# 5    10 MV     10KHZ    54391.1 -3.719940e+01  1.465270e-05  1.117260e-05
# 6    10 MV     10KHZ    54275.3 -3.719640e+01  1.465650e-05  1.116010e-05
# 7    10 MV     10KHZ    54262.0 -3.722620e+01  1.468880e-05  1.111880e-05
# 8    10 MV     20KHZ    38521.2 -1.891610e+04  2.093130e-05  1.025680e-05
# 9    10 MV     20KHZ    42794.9 -2.605250e+01  2.092740e-05  1.028790e-05
# 10   10 MV     20KHZ    42819.7 -2.606450e+01  2.090060e-05  1.030650e-05
# 11   10 MV     20KHZ    42830.0 -2.618510e+01  2.098020e-05  1.027470e-05
# ...

# %%
# Well 3
df3 = pd.read_csv('/home/james/Downloads/Well__3.txt')

df3.head(16)
# Out:
#    Voltage Frequency  Impedance       Phase  Conductance  Susceptance  \
# 0    10 MV     10KHZ    46839.3 -40555.4000     0.000017     0.000014
# 1    10 MV     10KHZ    45965.6    -39.7551     0.000017     0.000014
# 2    10 MV     10KHZ    45971.8    -39.7864     0.000017     0.000014
# 3    10 MV     10KHZ    45983.6    -39.7217     0.000017     0.000014
# 4    10 MV     10KHZ    45986.5    -39.7104     0.000017     0.000014
# 5    10 MV     10KHZ    46014.3    -39.7897     0.000017     0.000014
# 6    10 MV     10KHZ    45952.4    -39.7416     0.000017     0.000014
# 7    10 MV     10KHZ    45966.4    -39.7630     0.000017     0.000014
# 8    10 MV     20KHZ    35685.3    -27.9597     0.000025     0.000013
# 9    10 MV     20KHZ    35689.9    -27.9718     0.000025     0.000013
# 10   10 MV     20KHZ    35700.1    -27.9065     0.000025     0.000013
# 11   10 MV     20KHZ    35714.5    -27.8960     0.000025     0.000013
# ...

# %%
# Well 4
df4 = pd.read_csv('/home/james/Downloads/Well__4.txt')

df4.head(16)

#df4.info()
# Out:
#    Voltage Frequency  Impedance       Phase  Conductance  Susceptance  \
# 0    10 MV     10KHZ    40684.1 -40880.7000     0.000015     0.000013
# 1    10 MV     10KHZ    50913.8    -40.8197     0.000015     0.000013
# 2    10 MV     10KHZ    50919.0    -40.7614     0.000015     0.000013
# 3    10 MV     10KHZ    50811.5    -40.6628     0.000015     0.000013
# 4    10 MV     10KHZ    50848.7    -40.6867     0.000015     0.000013
# 5    10 MV     10KHZ    50789.2    -40.6951     0.000015     0.000013
# 6    10 MV     10KHZ    50791.7    -40.6357     0.000015     0.000013
# 7    10 MV     10KHZ    50733.8    -40.6425     0.000015     0.000013
# 8    10 MV     20KHZ    39150.1    -28.6360     0.000022     0.000012
# 9    10 MV     20KHZ    39158.8    -28.6962     0.000022     0.000012
# 10   10 MV     20KHZ    39288.8    -28.6523     0.000022     0.000012
# 11   10 MV     20KHZ    39177.5    -28.6893     0.000022     0.000012
# ...

# %%
# Declare any global variables

# counter=1

# We have 22968 entries.

# Want how many counters?

# HOW TO CREATE A NEW DATAFRAME:
# new = old[['A', 'C', 'D']].copy()
# new = old.filter(['A','B','D'], axis=1)

## Finally, depending on the number of columns in your original dataframe, it might be more succinct to express this using a drop (this will also create a copy by default):

# new = old.drop('B', axis=1)

# GOAL: To parse datafile into smaller dataframes -> multiple per file.

# Conditions:

# When voltage and frequency are the same, use binary as True. Use overlay and index?

for i=1:2871
        for j=1:8     # How many subsections are there? 8 subsections?
            for df1[df1['Voltage'] = 10 && df1['Frequency'] = 10]
            count = 1
            else if df1[df1['Voltage'] = (10 + 10*j) && df1['Frequency'] = (10 + 10*j)]
            count = 1 + j
            break
        break
break

df1_new = df1[['Voltage', 'Frequency']].copy()

Count_Column = [] #  Create 'Counter' column using count with [count[1],count[2], ..., count[j]]

# Use ".assign()" to add average of 1st, 1st std. dev., 2nd, 2nd std. dev, ...

# Use ".std()" and ".mean()".

# Using 'Counter' as the column name and equating it to the list 

df1_new = df1.assign(Count_Column) 
df1_new = df1.assign()

# Q: What do we need the standard deviation and mean of? 
# Y = Impedance, Susceptance, ..., etc.

for i in Count_Column

    avg_impedance[i] = df['Impedance'][i].mean()
    df1_new = df1.assign(avg_impedance[i]) # Add Avg. Impedance
    std_impedance[i] = df['Impedance'][i].std()
    df1_new = df1.assign(std_impedance[i]) # Add Std. Dev. of Impedance

    avg_phase[i] = df['Phase'][i].mean()
    df1_new = df1.assign(avg_phase[i]) # Add Avg. 
    std_phase[i] = df['Phase'][i].std()
    df1_new = df1.assign(std_phase[i]) # Add Std. Dev. 
    
    
    avg_conductance[i] = df['Conductance'][i].mean()
    df1_new = df1.assign(avg_impedance[i]) # Add Avg.
    std_conductance[i] = df['Conductance'][i].std()
    df1_new = df1.assign(std_conductance[i]) # Add Std. Dev. 
    
    avg_susceptance[i] = df['Susceptance'][i].mean()
    df1_new = df1.assign(avg_susceptance[i]) # Add Avg. 
    std_susceptance[i] = df['Susceptance'][i].std()
    df1_new = df1.assign(std_susceptance[i]) # Add Std. Dev. 
    
    avg_resistance[i] = df['Resistance'][i].mean()
    df1_new = df1.assign(avg_resistance[i]) # Add Avg. Impedance
    std_resistance[i] = df['Resistance'][i].std()
    df1_new = df1.assign(std_resistance[i]) # Add Std. Dev. of Impedance
    
    avg_reactance[i] = df['Reactance'][i].mean()
    df1_new = df1.assign(avg_reactance[i]) # Add Avg. Impedance
    std_reactance[i] = df['Reactance'][i].std()
    df1_new = df1.assign(std_reactance[i]) # Add Std. Dev. of Impedance
    
    
    
# Observe the result 
df1_new

# Do the same for df2, df3, df4.
# Out:
#   File "<ipython-input-1-a7a13b6e52fd>", line 19
#     for i=1:2871
#          ^
# SyntaxError: invalid syntax

# %%
# NOW: Want to plot multiple plots with error bars using matplotlib.

# Look up: How to plot multiple datasets using error bar with multicolor:

# Impedance:
plt.errorbar(x, y=(df1['Impedance'],df2['Impedance'],df3['Impedance'], df4['Impedance']),
                  xerr=xerr,
                  yerr=yerr,
                  label='trend',
                  fmt = '-', color = 'b',
                  # ecolor='xkcd: salmon', elinewidth=1.5,
                  # capsize = 5, capthick=2,
                  # barsabove=True,
                  # errorever=2
                  )
plt.xlabel('Sample Number')
plt.ylabel('Impedance')
plt.title('Impedance vs. Sample Number with all 4 Wells')
# plt.xticks()
# plt.yticks()
# plt.legend()
# plt.grid()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-dd485b60464b> in <module>
#       1 # NOW: Want to plot multiple plots with error bars using matplotlib.
#       2
# ----> 3 plt.errorbar(x, y=(df1['Impedance'],df2['Impedance'],df3['Impedance'], df4['Impedance']),
#       4                   xerr=xerr,
#       5                   yerr=yerr,
#
# NameError: name 'plt' is not defined

# %%
# Phase vs. Samples 
plt.errorbar(x, y=(df1['Phase'],df2['Phase'],df3['Phase'], df4['Phase']),
                  xerr=xerr,
                  yerr=yerr,
                  label='trend',
                  fmt = '-', color = 'b',
                  # ecolor='xkcd: salmon', elinewidth=1.5,
                  # capsize = 5, capthick=2,
                  # barsabove=True,
                  # errorever=2
                  )
plt.xlabel('Sample Number')
plt.ylabel('Phase')
plt.title('Phase vs. Sample Number with all 4 Wells')
# plt.xticks()
# plt.yticks()
# plt.legend()
# plt.grid()

# %%
# Conductance

plt.errorbar(x, y=(df1['Conductance'],df2['Conductance'],df3['Conductance'], df4['Conductance']),
                  xerr=xerr,
                  yerr=yerr,
                  label='trend',
                  fmt = '-', color = 'b',
                  # ecolor='xkcd: salmon', elinewidth=1.5,
                  # capsize = 5, capthick=2,
                  # barsabove=True,
                  # errorever=2
                  )
plt.xlabel('Sample Number')
plt.ylabel('Conductance')
plt.title('Conductance vs. Sample Number with all 4 Wells')
# plt.xticks()
# plt.yticks()
# plt.legend()
# plt.grid()

# %%
# Susceptance

plt.errorbar(x, y=(df1['Susceptance'],df2['Susceptance'],df3['Susceptance'], df4['Susceptance']),
                  xerr=xerr,
                  yerr=yerr,
                  label='trend',
                  fmt = '-', color = 'b',
                  # ecolor='xkcd: salmon', elinewidth=1.5,
                  # capsize = 5, capthick=2,
                  # barsabove=True,
                  # errorever=2
                  )
plt.xlabel('Sample Number')
plt.ylabel('Conductance')
plt.title('Susceptance vs. Sample Number with all 4 Wells')
# plt.xticks()
# plt.yticks()
# plt.legend()
# plt.grid()

# %%
# Resistance

plt.errorbar(x, y=(df1['Resistance'],df2['Resistance'],df3['Resistance'], df4['Resistance']),
                  xerr=xerr,
                  yerr=yerr,
                  label='trend',
                  fmt = '-', color = 'b',
                  # ecolor='xkcd: salmon', elinewidth=1.5,
                  # capsize = 5, capthick=2,
                  # barsabove=True,
                  # errorever=2
                  )
plt.xlabel('Sample Number')
plt.ylabel('Resistance')
plt.title('Resistance vs. Sample Number with all 4 Wells')
# plt.xticks()
# plt.yticks()
# plt.legend()
# plt.grid()

# %%
# Reactance

plt.errorbar(x, y=(df1['Reactance'],df2['Reactance'],df3['Reactance'], df4['Reactance']),
                  xerr=xerr,
                  yerr=yerr,
                  label='trend',
                  fmt = '-', color = 'b',
                  # ecolor='xkcd: salmon', elinewidth=1.5,
                  # capsize = 5, capthick=2,
                  # barsabove=True,
                  # errorever=2
                  )
plt.xlabel('Sample Number')
plt.ylabel('Reactance')
plt.title('Reactance vs. Sample Number with all 4 Wells')
# plt.xticks()
# plt.yticks()
# plt.legend()
# plt.grid()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-e36c457b5e7b> in <module>
#       1 # Reactance
#       2
# ----> 3 plt.errorbar(x, y=(df1['Reactance'],df2['Reactance'],df3['Reactance'], df4['Reactance']),
#       4                   xerr=xerr,
#       5                   yerr=yerr,
#
# NameError: name 'x' is not defined
